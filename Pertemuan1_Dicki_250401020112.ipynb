# %%
print("Hello, Data Science!")
print("Selamat datang di kuliah ini.")
# Out:
# Hello, Data Science!
# Selamat datang di kuliah ini.

# %%
nama = "Mahasiswa Informatika"
angkatan = 2024
ipk = 3.75
aktif = True

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Mahasiswa Informatika
# Angkatan: 2024
# IPK : 3.75
# Aktif : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Dicki Pramana Putra", "Informatika", 2026)
print(hasil)
# Out:
# Hai! Saya Dicki Pramana Putra dari Informatika, angkatan 2026.
